# %% [markdown]
# Author: Wishmith Dissanayaka 20221664

# %% [markdown]
# ```
# from sklearn import preprocessing
# from sklearn.model_selection import train_test_split
# from sklearn import tree
# from matplotlib import pyplot as plt
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.model_selection import GridSearchCV
# from sklearn import metrics
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import ConfusionMatrixDisplay
# from sklearn.metrics import classification_report
# from sklearn.metrics import RocCurveDisplay
# ```
#
# Tutorial 6 page 5

# %%
#import pandas
import pandas as pd

# Import train_test_split function
from sklearn.model_selection import train_test_split

# To construct and plot decision trees
from sklearn import tree
from matplotlib import pyplot as plt

# Import Decision Tree Classifier to predict loan approval status
from sklearn.tree import DecisionTreeClassifier

# Import Decision Tree Regressor to predict maximum loan amount
from sklearn.tree import DecisionTreeRegressor

#Import scikit-learn metrics module for classification and regression performance metrics
from sklearn import metrics

# %% [markdown]
# `data = pd.read_csv('/content/loan_approval_data.csv')`
#
# Tutorial 6 Page 5

# %%
#upload the dataset
data_frame = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/regression_dataset.csv')

# %% [markdown]
# `data_frame.shape`
#
# Tutorial 6 Page 5

# %%
# To look for any inconsistencies
data_frame.shape
# Out:
# (3956, 13)

# %% [markdown]
# `data_frame.info()`
#
# Tutorial 6 Page 5

# %%
# Column info
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3956 entries, 0 to 3955
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3956 non-null   int64
#  1   Sex                     3956 non-null   int64
#  2   T_Stage                 3956 non-null   int64
#  3   N_Stage                 3956 non-null   int64
#  4   6th_Stage               3956 non-null   int64
#  5   Grade                   3956 non-null   int64
#  6   A_Stage                 3956 non-null   int64
#  7   Tumor_Size              3956 non-null   int64
#  8   Estrogen_Status         3956 non-null   int64
#  9   Progesterone_Status     3956 non-null   int64
#  10  Regional_Node_Examined  3956 non-null   int64
#  11  Regional_Node_Positive  3956 non-null   int64
#  12  Survival_Months         3956 non-null   int64
# dtypes: int64(13)
# memory usage: 401.9 KB

# %%
# Display feature columns details
print('Whole Data shape', X.shape)
list(X.columns)
# Out:
# Whole Data shape (3956, 12)
# ['Age',
#  'Sex',
#  'T_Stage',
#  'N_Stage',
#  '6th_Stage',
#  'Grade',
#  'A_Stage',
#  'Tumor_Size',
#  'Estrogen_Status',
#  'Progesterone_Status',
#  'Regional_Node_Examined',
#  'Regional_Node_Positive']

# %%
data_frame.describe()
# Out:
#                Age     Sex      T_Stage      N_Stage    6th_Stage  \
# count  3956.000000  3956.0  3956.000000  3956.000000  3956.000000
# mean     53.994944     1.0     0.779323     0.431749     1.308392
# std       8.961836     0.0     0.761652     0.688459     1.259278
# min      30.000000     1.0     0.000000     0.000000     0.000000
# 25%      47.000000     1.0     0.000000     0.000000     0.000000
# 50%      54.000000     1.0     1.000000     0.000000     1.000000
# 75%      61.000000     1.0     1.000000     1.000000     2.000000
# max      69.000000     1.0     3.000000     2.000000     4.000000
#
#              Grade      A_Stage   Tumor_Size  Estrogen_Status  \
# count  3956.000000  3956.000000  3956.000000      3956.000000
# mean      2.140799     0.977503    30.275784         0.933771
# std       0.626950     0.148314    20.814794         0.248713
# min       1.000000     0.000000     1.000000         0.000000
# ...

# %% [markdown]
# `X = df_loan_status.drop(['loan_approval_status', 'id'], axis=1)`
# `y = df_loan_status['loan_approval_status']`
# `X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=43, stratify=y)`
#
# Tute 6 Page 13

# %%
# Dataset feature variables
X = data_frame.drop('Survival_Months', axis=1)

# Dataset target variable
y = data_frame['Survival_Months']

#Split the dataset in 60% Training and 40% Test with class stratification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=43)

# %% [markdown]
# `DT_regressor = DecisionTreeRegressor()`
# `DT_regressor.fit(X_train, y_train)`
#
# Code Reuse Session 3

# %%
# To train the DT regression algorithm
DT_regressor = DecisionTreeRegressor()
DT_regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# `y_pred = DT_regressor.predict(X_test)`
#
# Code Reuse Session 3

# %%
# To make predictions on the test set, ues the predict method:
y_pred = DT_regressor.predict(X_test)
# Display the tree's depth
print("The full Regression Decision Tree Levels: ", DT_regressor.tree_.max_depth)
# Out:
# The full Regression Decision Tree Levels:  27

# %% [markdown]
# `from sklearn import metrics`
# `print('MAE:', metrics.mean_absolute_error(y_test, y_pred))`
# `print('MSE:', metrics.mean_squared_error(y_test, y_pred))`
# `print('R2:', metrics.r2_score(y_test, y_pred))`
#
# Code Reuse Session 3

# %%
# To calculate the regression metrics
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('R2:', metrics.r2_score(y_test, y_pred))
# Out:
# MAE: 25.540016849199663
# MSE: 1006.8934288121314
# R2: -1.004456565699392

# %% [markdown]
# ```
# Tree_figure = plt.figure(figsize=(200,200))
# DT_Graph = tree.plot_tree(DT_regressor, feature_names=list(X_train.columns), filled=True)
# Tree_figure.savefig("decistion_tree.svg")
# ```
#
# Code Reuse Session 3

# %%
# Plots Fully Grown Decision Tree model for survival months
Tree_figure = plt.figure(figsize=(20,12))
DT_Graph = tree.plot_tree(DT_regressor, feature_names=list(X_train.columns), filled=True)

# Saves DT graph as an image
Tree_figure.savefig("decision_tree.png")

# %% [markdown]
# `DT_regressor = DecisionTreeRegressor(max_depth=value)`
# `DT_regressor.fit(X_train, y_train)`
# `y_pred = DT_regressor.predict(X_test)`
#
# Code Resuse Session 3

# %%
# Limit tree depth to 4 levels
Pruned_DT_regressor = DecisionTreeRegressor(max_depth=4)
Pruned_DT_regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4)

# %%
# To make predictions on the test set
pruned_y_pred = Pruned_DT_regressor.predict(X_test)

# %% [markdown]
# `from sklearn import metrics`
# `print('MAE:', metrics.mean_absolute_error(y_test, y_pred))`
# `print('MSE:', metrics.mean_squared_error(y_test, y_pred))`
# `print('R2:', metrics.r2_score(y_test, y_pred))`
#
# Code Reuse Session 3

# %%
# Calculating the regression metrics for the pruned regression decision Tree
print('MAE:', metrics.mean_absolute_error(y_test, pruned_y_pred))
print('MSE:', metrics.mean_squared_error(y_test, pruned_y_pred))
print('R2:', metrics.r2_score(y_test, pruned_y_pred))
# Out:
# MAE: 18.328522314538592
# MSE: 505.1304987535235
# R2: -0.005580248900825424

# %% [markdown]
# ```
# Tree_figure = plt.figure(figsize=(200,200))
# DT_Graph = tree.plot_tree(DT_regressor, feature_names=list(X_train.columns), filled=True)
# Tree_figure.savefig("decistion_tree.svg")
# ```
#
# Code Reuse Session 3

# %%
# Plots Pruned Decision Tree model for survival months
Tree_figure = plt.figure(figsize=(20,12))
DT_Graph = tree.plot_tree(Pruned_DT_regressor, feature_names=list(X_train.columns), filled=True)

# Saves DT graph as an image
Tree_figure.savefig("pruned_decision_tree.png")

# %% [markdown]
# # **Ensemble Learning**

# %% [markdown]
# ```
# from sklearn import preprocessing
# from sklearn.model_selection import train_test_split
# from sklearn import tree
# from matplotlib import pyplot as plt
# from sklearn.tree import DecisionTreeClassifier
# from sklearn.tree import DecisionTreeRegressor
# from sklearn.model_selection import GridSearchCV
# from sklearn import metrics
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import ConfusionMatrixDisplay
# from sklearn.metrics import classification_report
# from sklearn.metrics import RocCurveDisplay
# ```
#
# Tutorial 6 page 5

# %%
# Import libraries
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import RocCurveDisplay

# Import the function to calculate accuracy score
from sklearn.metrics import accuracy_score

# Import GaussianNB from sklearn
from sklearn.naive_bayes import GaussianNB

#initiate a new ensemble model
from sklearn.ensemble import VotingClassifier

# %% [markdown]
# `data = pd.read_csv('/content/loan_approval_data.csv')`
#
# Tutorial 6 Page 5

# %%
# Load Dataset
data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/classification_dataset.csv')

# %% [markdown]
# `data.head()`
#
# Code Reuse Session 3

# %%
# Display the first few rows
data.head()
# Out:
#    Age  Sex  T_Stage  N_Stage  6th_Stage  Grade  A_Stage  Tumor_Size  \
# 0   68    1        0        0          0      3        1           4
# 1   50    1        1        1          2      2        1          35
# 2   58    1        2        2          4      2        1          63
# 3   58    1        0        0          0      3        1          18
# 4   47    1        1        0          1      3        1          41
#
#    Estrogen_Status  Progesterone_Status  Regional_Node_Examined  \
# 0                1                    1                      24
# 1                1                    1                      14
# 2                1                    1                      14
# 3                1                    1                       2
# 4                1                    1                       3
#
#    Regional_Node_Positive  Mortality_Status
# 0                       1                 0
# 1                       5                 0
# ...

# %% [markdown]
# `data.info()`
#
# Code Reuse Session 3

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3956 entries, 0 to 3955
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3956 non-null   int64
#  1   Sex                     3956 non-null   int64
#  2   T_Stage                 3956 non-null   int64
#  3   N_Stage                 3956 non-null   int64
#  4   6th_Stage               3956 non-null   int64
#  5   Grade                   3956 non-null   int64
#  6   A_Stage                 3956 non-null   int64
#  7   Tumor_Size              3956 non-null   int64
#  8   Estrogen_Status         3956 non-null   int64
#  9   Progesterone_Status     3956 non-null   int64
#  10  Regional_Node_Examined  3956 non-null   int64
#  11  Regional_Node_Positive  3956 non-null   int64
#  12  Mortality_Status        3956 non-null   int64
# dtypes: int64(13)
# memory usage: 401.9 KB

# %% [markdown]
# `data_frame.shape`
#
# Tutorial 6 Page 5

# %%
# dataset dimentions
data.shape
# Out:
# (3956, 13)

# %% [markdown]
# `feature_cols = ['input_feature1_name', 'input_feature2_name', 'input_feature3_name', 'input_feature4_name', ...]`
# `X = data[feature_cols] # Features`
# `y = data['target_feature_name']`
#
# Code Reuse Session 3

# %%
# Feature columns
feature_cols = ['Age', 'Sex','T_Stage', 'N_Stage', '6th_Stage', 'Grade', 'A_Stage', 'Tumor_Size', 'Estrogen_Status', 'Progesterone_Status', 'Regional_Node_Examined', 'Regional_Node_Positive']

# Features in data_frame as input variables
X = data[feature_cols]

# Target variables
y = data['Mortality_Status']

# %% [markdown]
# `X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=value, random_state=value, stratify=y)`
#
# Code Reuse Session 3

# %%
# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %% [markdown]
# `from sklearn.preprocessing import StandardScaler`
# `scaler = StandardScaler()`
# `X1 = scaler.fit_transform(X)`
#
# Tute 3 Page 8

# %%
# Using standardization to scale your input features.
scaler = StandardScaler()
X1_train = scaler.fit_transform(X_train)
X1_test = scaler.transform(X_test)

# %% [markdown]
# `from sklearn.linear_model import LogisticRegression`
# `logreg = LogisticRegression()`
# `logreg.fit(X1_train, y_train)`
# `y_pred=logreg.predict(X1_test)`
#
# Tute 3 Page 9

# %%
# import the LR algorithm, build the LR model then test it by predicting on the test data
lr = LogisticRegression(random_state=42)
lr = lr.fit(X1_train,y_train)
y_pred_lr = lr.predict(X1_test)

# %% [markdown]
# `from sklearn.metrics import classification_report`
# `print(classification_report(y_test, y_pred))`
#
# Tute 3 Page 11

# %%
# Evaluating LR model by generating the classification report and the confusion matrix
print(classification_report(y_test,y_pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.99      0.92      1007
#            1       0.65      0.14      0.24       180
#
#     accuracy                           0.86      1187
#    macro avg       0.76      0.57      0.58      1187
# weighted avg       0.83      0.86      0.82      1187

# %% [markdown]
# `from sklearn.metrics import confusion_matrix`
# `from sklearn.metrics import ConfusionMatrixDisplay`
# `cm = confusion_matrix(y_test, y_pred, labels=logreg.classes_)`
# `disp = ConfusionMatrixDisplay(cm,display_labels=logreg.classes_)`
# `disp.plot()`
#
# Tute 3 Page 10

# %%
# Evaluating LR model by generating the confusion matrix
lr_cm = confusion_matrix(y_test,y_pred_lr)
disp = ConfusionMatrixDisplay(confusion_matrix=lr_cm,display_labels=lr.classes_)
disp.plot()

# %% [markdown]
# `from sklearn.metrics import accuracy_score`
# `accuracy = accuracy_score(y_test,y_pred) `
# `print ('The Logistic Regression Model Accuracy:',accuracy)`
#
# Tute 3 Page 10

# %%
# Accuracy of the LR model
LR_accuracy = accuracy_score(y_test, y_pred_lr)
print ("The Logistic Regression model accuracy is: ", LR_accuracy)
# Out:
# The Logistic Regression model accuracy is:  0.8584667228306655

# %%
#ROC curve logistic regression
from sklearn.metrics import roc_curve, auc
fpr_lr, tpr_lr, thresholds = roc_curve(y_test, y_pred_lr)
roc_auc_lr = auc(fpr_lr, tpr_lr)
plt.figure(figsize=(8, 6))
plt.plot(fpr_lr, tpr_lr, label=f"Logistic Regression (AUC = {roc_auc_lr:.2f})", color='blue')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Logistic Regression')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# `from sklearn.naive_bayes import GaussianNB`
# `nb = GaussianNB()`
# `nb.fit(X1_train, y_train)`
# `y_pred=nb.predict(X1_test)`
#
# Tute 4 Page 14

# %%
# import the NB algorithm, build the NB model then test it by predicting on the test data
nb = GaussianNB()
nb.fit(X1_train, y_train)
y_pred_nb = nb.predict(X1_test)

# %% [markdown]
# `print(classification_report(y_test, y_pred))`
#
# Tute 4 Page 15

# %%
# Evaluating NB model by generating the classification report and the confusion matrix
print(classification_report(y_test,y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87      1007
#            1       0.33      0.38      0.35       180
#
#     accuracy                           0.79      1187
#    macro avg       0.61      0.62      0.61      1187
# weighted avg       0.80      0.79      0.79      1187

# %% [markdown]
# `from sklearn.metrics import confusion_matrix`
# `from sklearn.metrics import ConfusionMatrixDisplay`
# `nb_cm = confusion_matrix(y_test, y_pred, labels = nb.classes_)`
# `nb_cm = ConfusionMatrixDisplay(nb_cm, display_labels = nb.classes_)`
# `nb_cm.plot()`
#
# Tute 4 Page 15

# %%
# Evaluating NB model by generating the confusion matrix
nb_cm = confusion_matrix(y_test,y_pred_nb)
disp = ConfusionMatrixDisplay(confusion_matrix=nb_cm,display_labels=nb.classes_)
disp.plot()

# %% [markdown]
# `from sklearn.metrics import accuracy_score`
# `accuracy = accuracy_score(y_test,y_pred) `
# `print ('The Logistic Regression Model Accuracy:',accuracy)`
#
# Tute 3 Page 10

# %%
# Accuracy of the NB model
NB_accuracy = accuracy_score(y_test, y_pred_nb)
print ("The naïve bayes model accuracy is: ", NB_accuracy)
# Out:
# The naïve bayes model accuracy is:  0.7860151642796968

# %%
#ROC curve logistic regression
from sklearn.metrics import roc_curve, auc
fpr_lr, tpr_lr, thresholds = roc_curve(y_test, y_pred_nb)
roc_auc_lr = auc(fpr_lr, tpr_lr)
plt.figure(figsize=(8, 6))
plt.plot(fpr_lr, tpr_lr, label=f"Naive Bayes (AUC = {roc_auc_lr:.2f})", color='blue')
plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve - Naive Bayes')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()

# %% [markdown]
# `base_learners=[('Algorithm1', Algorithm1), ('Algorithm2', Algorithm2)]`
# `ensemble_learner = VotingClassifier(base_learners, voting='soft')`
# `ensemble_learner.fit(X_train, y_train)`
# `y_pred_ensemble_learner = ensemble_learner.predict(X_test)`
#
# Code Reuse Session 3

# %%
# Create a dictionary of base learner models
base_learners=[('NB', nb), ('LR', lr)]
# Create voting classifier
ensemble_learner = VotingClassifier(base_learners, voting='soft')
# Fit model to training data
ensemble_learner = ensemble_learner.fit(X1_train, y_train)
y_pred_ensemble_learner = ensemble_learner.predict(X1_test)

# %% [markdown]
# `from sklearn.metrics import accuracy_score`
# `ensemble_learner_accuracy = accuracy_score(y_test, y_pred_ensemble_learner)`
# `print ("The voting ensemble classifier accuracy is: ", ensemble_learner_accuracy)`
#
# Code Reuse Session 3

# %%
# Ensemble learner accuracy
ensemble_learner_accuracy = accuracy_score(y_test, y_pred_ensemble_learner)
print ("The voting ensemble classifier accuracy is: ", ensemble_learner_accuracy)
# Out:
# The voting ensemble classifier accuracy is:  0.7944397641112048

# %% [markdown]
# ```
# from sklearn.metrics import confusion_matrix
# from sklearn.metrics import ConfusionMatrixDisplay
# ensemble_learner_cm_test = confusion_matrix(y_test, y_pred_ensemble_learner, labels=ensemble_learner.classes_)
# ensemble_learner_disp = ConfusionMatrixDisplay(ensemble_learner_cm_test,display_labels=ensemble_learner.classes_)
# ensemble_learner_disp.plot()
# ensemble_learner_disp.ax_.set_title("Ensemble Learner Confusion Matrix")
# ```
#
# Code Reuse Session 3

# %%
# Ensemble learner confusion matrix
ensemble_learner_cm_test = confusion_matrix(y_test, y_pred_ensemble_learner, labels=ensemble_learner.classes_)
ensemble_learner_disp = ConfusionMatrixDisplay(ensemble_learner_cm_test,display_labels=ensemble_learner.classes_)
ensemble_learner_disp.plot()
ensemble_learner_disp.ax_.set_title("Ensemble Learner Confusion Matrix")
# Out:
# Text(0.5, 1.0, 'Ensemble Learner Confusion Matrix')

# %% [markdown]
# `from sklearn.metrics import classification_report`
# `print("Ensemble Learner Classification Report \n", classification_report(y_test, y_pred_ensemble_learner))`
#
# Code Reuse Session 3

# %%
# Ensemble learner classification report
print("Ensemble Learner Classification Report \n", classification_report(y_test, y_pred_ensemble_learner))
# Out:
# Ensemble Learner Classification Report
#                precision    recall  f1-score   support
#
#            0       0.88      0.87      0.88      1007
#            1       0.34      0.37      0.35       180
#
#     accuracy                           0.79      1187
#    macro avg       0.61      0.62      0.61      1187
# weighted avg       0.80      0.79      0.80      1187

# %% [markdown]
# `from sklearn.metrics import RocCurveDisplay`
# `ensemble_learner = RocCurveDisplay.from_estimator(ensemble_learner, X_test, y_test)`
#
# Code Reuse Session 3

# %%
# Ensemble learner Roc Curve
ensemble_learner = RocCurveDisplay.from_estimator(ensemble_learner, X_test, y_test)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but GaussianNB was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(
